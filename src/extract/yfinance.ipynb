# %%
import yfinance as yf
import pandas as pd

# %%
all_tickers = pd.read_excel(
    r"C:\Users\zakis\Downloads\Daftar Saham  - 20260707.xlsx"
)

all_tickers.head()
# Out:
#    No  Kode                Nama Perusahaan Tanggal Pencatatan           Saham  \
# 0   1  AALI        Astra Agro Lestari Tbk.        09 Des 1997   1.924.688.333
# 1   2  ABBA              Mahaka Media Tbk.        03 Apr 2002   3.935.892.857
# 2   3  ABDA   Asuransi Bina Dana Arta Tbk.        06 Jul 1989     620.806.680
# 3   4  ABMM             ABM Investama Tbk.        06 Des 2011   2.753.165.000
# 4   5  ACES  Aspirasi Hidup Indonesia Tbk.        06 Nov 2007  17.120.389.700
#
#     Papan Pencatatan
# 0              Utama
# 1  Pemantauan Khusus
# 2       Pengembangan
# 3              Utama
# 4              Utama

# %%
all_tickers.to_json(r"C:\Users\zakis\OneDrive\Desktop\indonesia-stock-pipeline\data\indonesian_stock_list.json", orient="records", force_ascii=False, indent=4)
